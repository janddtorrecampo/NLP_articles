# %% [markdown]
# # Final Project: NLP
#
# >It’s a little like a theater where someone yells 'Fire!'.**Glaberson 1987**
#
#
# ![image.png](attachment:image.png)
#
#
# ## 1. Preprocessing
# ##### exploratory analysis
# ##### Beautiful Soup
# ##### lowercase all
# ##### stopword removal
# ##### tokenization
# ##### stemming or lemmatization
#
#
# ## 2. Processing Measures
# ##### Bag the words- word frequency
# ##### Co-occurrence
# ##### Named Entity Recognition
# ##### Sentiment Analysis
# ##### Term Frequency Inverse Document Frequency (TF-IDF)
#
# A term frequency inverse document frequency (TF-IDF) matrix creates a weighted score for how important a term is per document in a corpus. The first is the ‘term frequency (TF),’ or how often the word appeared within that document. It makes intuitive sense that if a word appears many times in a document, that the document is about something related to that term. The second attribute is the ‘inverse document frequency (IDF),’ a measure of what proportion of the documents the word appeared in. If a word appears in all documents, its weight should be reduced. Conversely, if a word appears only in few documents, it should be highly weighted for those documents.
#
# The formula for TF-IDF is: tfidf(t,d,D) = tf(t,d) * idf(t,D)
#
# ## 3. Topic Models
#
#
# ## 1. Preprocessing
# ##### exploratory analysis
# ##### Beautiful Soup
# ##### lowercase all
# ##### stopword removal
# ##### tokenization
# ##### stemming or lemmatization
#
#
# ## 2. Processing Measures
# ##### Bag the words- word frequency
# ##### Co-occurrence
# ##### Named Entity Recognition
# ##### Sentiment Analysis
# ##### Term Frequency Inverse Document Frequency (TF-IDF)
#
# A term frequency inverse document frequency (TF-IDF) matrix creates a weighted score for how important a term is per document in a corpus. The first is the ‘term frequency (TF),’ or how often the word appeared within that document. It makes intuitive sense that if a word appears many times in a document, that the document is about something related to that term. The second attribute is the ‘inverse document frequency (IDF),’ a measure of what proportion of the documents the word appeared in. If a word appears in all documents, its weight should be reduced. Conversely, if a word appears only in few documents, it should be highly weighted for those documents.
#
# The formula for TF-IDF is: tfidf(t,d,D) = tf(t,d) * idf(t,D)
#
# ## 3. Topic Models

# %%
import nltk
nltk.download('punkt')

import glob
import numpy as np
import matplotlib.pyplot as plt
import gensim
import pandas as pd
import math
import pickle
from bs4 import BeautifulSoup
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\faria\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %% [markdown]
# ## Initial Exploratory Analysis

# %%
pwd
# Out:
# 'C:\\Users\\faria\\OneDrive\\Desktop\\Final_Tiago'

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 3CA7-BD92
#
#  Directory of C:\Users\faria\OneDrive\Desktop\Final_Tiago
#
# 17/10/2022  10:47    <DIR>          .
# 16/10/2022  00:04    <DIR>          ..
# 17/10/2022  10:47    <DIR>          .ipynb_checkpoints
# 04/12/1996  19:27               186 all-exchanges-strings.lc.txt
# 04/12/1996  19:27               316 all-orgs-strings.lc.txt
# 04/12/1996  19:27             2ÿ474 all-people-strings.lc.txt
# 04/12/1996  19:27             1ÿ721 all-places-strings.lc.txt
# 04/12/1996  19:27             1ÿ005 all-topics-strings.lc.txt
# 02/06/2022  19:38           600ÿ686 Captura de ecrÆ 2022-06-02 193821.png
# 13/06/2022  13:26               393 Code_1.txt
# 23/06/2022  11:17        17ÿ426ÿ597 DATA_CSV
# 23/06/2022  11:04        17ÿ426ÿ597 DATA_CSV.txt
# 09/09/2022  13:15           565ÿ292 Dudensing_Paystubs_BuckleyLaw.pdf
# 22/06/2022  18:56           137ÿ418 EA.ipynp
# 10/12/1996  04:32           273ÿ802 feldman-cia-worldfactbook-data.txt
# 01/06/2022  15:45             1ÿ078 Final_Tiago - Atalho.lnk
# 23/06/2022  10:00            36ÿ002 IMAGE.jfif
# 23/01/1997  15:14             1ÿ485 lewis.dtd
# 23/06/2022  09:24            27ÿ690 ML_Projecto_sprint (1).pynb
# 17/06/2022  18:17        11ÿ628ÿ034 ML_Projecto_sprint.ipynb
# 23/06/2022  09:12            27ÿ690 ML_Projecto_sprint_final.pynb
# 30/06/2022  18:04         1ÿ744ÿ399 NPL_beautifulsoup.ipynb
# 20/05/2022  12:29        12ÿ676ÿ267 NYT_Corpus.txt
# 26/09/1997  15:15            36ÿ388 README.txt
# 04/12/1996  19:26         1ÿ324ÿ350 reut2-000.sgm
# 04/12/1996  19:26         1ÿ254ÿ440 reut2-001.sgm
# 04/12/1996  19:26         1ÿ217ÿ495 reut2-002.sgm
# 04/12/1996  19:26         1ÿ298ÿ721 reut2-003.sgm
# 04/12/1996  19:26         1ÿ321ÿ623 reut2-004.sgm
# 04/12/1996  19:26         1ÿ388ÿ644 reut2-005.sgm
# 04/12/1996  19:26         1ÿ254ÿ765 reut2-006.sgm
# 04/12/1996  19:26         1ÿ256ÿ772 reut2-007.sgm
# 04/12/1996  19:26         1ÿ410ÿ117 reut2-008.sgm
# 04/12/1996  19:26         1ÿ338ÿ903 reut2-009.sgm
# 04/12/1996  19:26         1ÿ371ÿ071 reut2-010.sgm
# 04/12/1996  19:26         1ÿ304ÿ117 reut2-011.sgm
# 04/12/1996  19:26         1ÿ323ÿ584 reut2-012.sgm
# 04/12/1996  19:26         1ÿ129ÿ687 reut2-013.sgm
# 04/12/1996  19:26         1ÿ128ÿ671 reut2-014.sgm
# 04/12/1996  19:26         1ÿ258ÿ665 reut2-015.sgm
# 04/12/1996  19:26         1ÿ316ÿ417 reut2-016.sgm
# 04/12/1996  19:26         1ÿ546ÿ911 reut2-017.sgm
# 04/12/1996  19:26         1ÿ258ÿ819 reut2-018.sgm
# 04/12/1996  19:26         1ÿ261ÿ780 reut2-019.sgm
# 04/12/1996  19:26         1ÿ049ÿ566 reut2-020.sgm
# 04/12/1996  19:26           621ÿ648 reut2-021.sgm
# 27/05/2022  00:17    <DIR>          reuters21578
# 29/06/2022  09:58        12ÿ326ÿ572 Sprint 5_Cat
# 30/06/2022  18:38         1ÿ742ÿ471 Sprint_ML..ipynb
# 30/06/2022  18:23         1ÿ923ÿ751 Sprint_Test.ipynb
# 11/06/2022  11:16         2ÿ166ÿ578 sprint-1.ipynb
# 23/06/2022  09:06         9ÿ559ÿ798 Sprint4Catarina.ipynb
# 20/05/2022  16:14            69ÿ476 Tiago_notebook1_Test_May3.ipynb
# 27/05/2022  01:15            82ÿ732 UCI.ipynb
# 02/06/2022  12:22        13ÿ042ÿ203 Unsupervised.ipynb
# 11/06/2022  11:05         1ÿ042ÿ526 Untitled5.ipynb
# 22/06/2022  20:22             1ÿ237 Untitled6.ipynb
# 23/06/2022  15:32             4ÿ820 Untitled7.ipynb
# 20/05/2022  16:03           290ÿ489 WhatsApp Image 2022-05-20 at 4.02.32 PM.jpeg
# 31/05/2022  10:57            65ÿ033 WhatsApp Image 2022-05-31 at 8.51.18 AM.jpeg
#               56 File(s)    132ÿ569ÿ972 bytes
#                4 Dir(s)  899ÿ886ÿ444ÿ544 bytes free

# %% [markdown]
# ## Need to extract the SGM files

# %%
# a quick method to filter out the sgm files and create a list
files = glob.glob("*.sgm")
print(files)
# Out:
# ['reut2-000.sgm', 'reut2-001.sgm', 'reut2-002.sgm', 'reut2-003.sgm', 'reut2-004.sgm', 'reut2-005.sgm', 'reut2-006.sgm', 'reut2-007.sgm', 'reut2-008.sgm', 'reut2-009.sgm', 'reut2-010.sgm', 'reut2-011.sgm', 'reut2-012.sgm', 'reut2-013.sgm', 'reut2-014.sgm', 'reut2-015.sgm', 'reut2-016.sgm', 'reut2-017.sgm', 'reut2-018.sgm', 'reut2-019.sgm', 'reut2-020.sgm', 'reut2-021.sgm']

# %%
#curious about the number of files
len(files)
# Out:
# 22

# %%
#while there is only 22 files, you can see that there are 21,578 documents, which my collegues have determined contain some duplicates
docs=[]
for file in files:  
    with open(file, encoding='cp1252') as text:
        article = text.read()
        soup = BeautifulSoup(article, 'html.parser')
        for a in soup.find_all('reuters'):
            docs.append(a)
            #print(docs) tried but computer crashed
len(docs)
# Out:
# 21578

# %%
#clean the dates up
clean_dates = []
for i in range(0, len(docs)):
    if docs[i].date:
        clean_dates.append(docs[i].date.text)
print(clean_dates)
# Out:
# ['26-FEB-1987 15:01:01.79', '26-FEB-1987 15:02:20.00', '26-FEB-1987 15:03:27.51', '26-FEB-1987 15:07:13.72', '26-FEB-1987 15:10:44.60', '26-FEB-1987 15:14:36.41', '26-FEB-1987 15:14:42.83', '26-FEB-1987 15:15:40.12', '26-FEB-1987 15:17:11.20', '26-FEB-1987 15:18:06.67', '26-FEB-1987 15:18:59.34', '26-FEB-1987 15:19:15.45', '26-FEB-1987 15:20:13.09', '26-FEB-1987 15:20:27.17', '26-FEB-1987 15:20:48.43', '26-FEB-1987 15:21:16.13', '26-FEB-1987 15:24:48.56', '26-FEB-1987 15:26:26.78', '26-FEB-1987 15:26:54.12', '26-FEB-1987 15:32:03.12', '26-FEB-1987 15:33:23.61', '26-FEB-1987 15:34:07.03', '26-FEB-1987 15:34:16.30', '26-FEB-1987 15:35:16.67', '26-FEB-1987 15:35:39.38', '26-FEB-1987 15:36:44.78', '26-FEB-1987 15:36:53.42', '26-FEB-1987 15:38:26.23', '26-FEB-1987 15:39:41.92', '26-FEB-1987 15:41:56.54', '26-FEB-1987 15:43:14.36', '26-FEB-1987 15:43:59.53', '26-FEB-1987 15:44:36.04', '26-FEB-1987 15:45:19.65', '26-FEB-1987 15:45:26.55', '26-FEB-1987 15:45:35.37', '26-FEB-1987 15:45:39.20', '26-FEB-1987 15:45:47.29', '26-FEB-1987 15:46:36.16', '26-FEB-1987 15:47:16.17', '26-FEB-1987 15:48:26.92', '26-FEB-1987 15:49:27.16', '26-FEB-1987 15:49:44.93', '26-FEB-1987 15:49:56.01', '26-FEB-1987 15:51:17.84', '26-FEB-1987 15:51:28.42', '26-FEB-1987 15:51:51.24', '26-FEB-1987 15:52:15.10', '26-FEB-1987 15:52:25.60', '26-FEB-1987 15:52:33.04', '26-FEB-1987 15:52:57.49', '26-FEB-1987 15:53:05.48', '26-FEB-1987 15:53:54.56', '26-FEB-1987 15:54:55.20', '26-FEB-1987 15:56:00.50', '26-FEB-1987 15:57:48.22', '26-FEB-1987 15:58:07.34', '26-FEB-1987 15:58:19.46', '26-FEB-1987 15:58:47.73', '26-FEB-1987 16:03:15.46', '26-FEB-1987 16:04:05.90', '26-FEB-1987 16:04:57.16', '26-FEB-1987 16:05:36.23', '26-FEB-1987 16:06:36.68', '26-FEB-1987 16:07:14.07', '26-FEB-1987 16:07:27.81', '26-FEB-1987 16:08:15.22', '26-FEB-1987 16:08:33.15', '26-FEB-1987 16:10:43.67', '26-FEB-1987 16:11:21.94', '26-FEB-1987 16:12:01.46', '26-FEB-1987 16:13:04.20', '26-FEB-1987 16:13:36.47', '26-FEB-1987 16:14:23.26', '26-FEB-1987 16:15:51.34', '26-FEB-1987 16:16:52.92', '26-FEB-1987 16:17:05.96', '26-FEB-1987 16:17:21.41', '26-FEB-1987 16:18:41.47', '26-FEB-1987 16:20:06.60', '26-FEB-1987 16:20:50.93', '26-FEB-1987 16:23:47.79', '26-FEB-1987 16:25:23.18', '26-FEB-1987 16:25:42.65', '26-FEB-1987 16:26:09.46', '26-FEB-1987 16:27:07.38', '26-FEB-1987 16:29:15.25', '26-FEB-1987 16:29:19.68', '26-FEB-1987 16:29:26.29', '26-FEB-1987 16:29:30.05', '26-FEB-1987 16:29:56.33', '26-FEB-1987 16:31:34.18', '26-FEB-1987 16:31:44.49', '26-FEB-1987 16:31:54.04', '26-FEB-1987 16:32:04.32', '26-FEB-1987 16:32:37.30', '26-FEB-1987 16:32:51.69', '26-FEB-1987 16:33:15.81', '26-FEB-1987 16:34:34.40', '26-FEB-1987 16:35:16.02', '26-FEB-1987 16:35:24.57', '26-FEB-1987 16:36:26.90', '26-FEB-1987 16:36:54.20', '26-FEB-1987 16:38:46.25', '26-FEB-1987 16:38:54.88', '26-FEB-1987 16:39:03.54', '26-FEB-1987 16:40:00.82', '26-FEB-1987 16:40:34.32', '26-FEB-1987 16:41:34.44', '26-FEB-1987 16:43:13.65', '26-FEB-1987 16:44:35.29', '26-FEB-1987 16:45:08.59', '26-FEB-1987 16:45:44.50', '26-FEB-1987 16:47:45.09', '26-FEB-1987 16:47:53.20', '26-FEB-1987 16:48:02.07', '26-FEB-1987 16:48:18.55', '26-FEB-1987 16:48:26.74', '26-FEB-1987 16:48:35.83', '26-FEB-1987 16:48:40.42', '26-FEB-1987 16:48:55.38', '26-FEB-1987 16:50:26.50', '26-FEB-1987 16:57:27.21', '26-FEB-1987 16:58:09.48', '26-FEB-1987 16:59:25.38', '26-FEB-1987 16:59:41.32', '26-FEB-1987 17:00:56.04', '26-FEB-1987 17:01:28.10', '26-FEB-1987 17:02:22.77', '26-FEB-1987 17:05:08.18', '26-FEB-1987 17:06:06.68', '26-FEB-1987 17:07:18.66', '26-FEB-1987 17:07:44.45', '26-FEB-1987 17:08:27.52', '26-FEB-1987 17:09:47.78', '26-FEB-1987 17:11:01.51', '26-FEB-1987 17:11:26.97', '26-FEB-1987 17:24:42.88', '26-FEB-1987 17:32:15.34', '26-FEB-1987 17:32:49.67', '26-FEB-1987 17:33:05.21', '26-FEB-1987 17:33:25.81', '26-FEB-1987 17:33:29.55', '26-FEB-1987 17:34:11.89', '26-FEB-1987 17:34:23.04', '26-FEB-1987 17:34:40.53', '26-FEB-1987 17:34:45.19', '26-FEB-1987 17:34:52.72', '26 ...

# %%
# create a dataframe
df_dates = pd.DataFrame({
    'Date': clean_dates
})
# display the dataframe
print(df_dates)
# Out:
#                           Date
# 0      26-FEB-1987 15:01:01.79
# 1      26-FEB-1987 15:02:20.00
# 2      26-FEB-1987 15:03:27.51
# 3      26-FEB-1987 15:07:13.72
# 4      26-FEB-1987 15:10:44.60
# ...                        ...
# 21573  19-OCT-1987 00:34:08.94
# 21574  19-OCT-1987 00:18:22.79
# 21575  19-OCT-1987 00:05:11.26
# 21576  19-OCT-1987 00:03:21.69
# 21577  19-OCT-1987 13:30:41.59
#
# [21578 rows x 1 columns]

# %%
titles = []
for i in range(0, len(docs)):
    if docs[i].title:
        titles.append(docs[i].title.text)
print(titles)
# Out:
# ['BAHIA COCOA REVIEW', 'STANDARD OIL <SRD> TO FORM FINANCIAL UNIT', 'TEXAS COMMERCE BANCSHARES <TCB> FILES PLAN', 'TALKING POINT/BANKAMERICA <BAC> EQUITY OFFER', 'NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE', 'ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS', 'RED LION INNS FILES PLANS OFFERING', "USX <X> DEBT DOWGRADED BY MOODY'S", 'CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT', 'COMPUTER TERMINAL SYSTEMS <CPML> COMPLETES SALE', 'COBANCO INC <CBCO> YEAR NET', 'OHIO MATTRESS <OMT> MAY HAVE LOWER 1ST QTR NET', 'AM INTERNATIONAL INC <AM> 2ND QTR JAN 31', 'BROWN-FORMAN INC <BFD> 4TH QTR NET', 'NATIONAL INTERGROUP<NII> TO OFFER PERMIAN UNITS', 'ECONOMIC SPOTLIGHT - BANKAMERICA <BAC>', 'NATIONAL HEALTH ENHANCEMENT <NHES> NEW PROGRAM', 'DEAN FOODS <DF> SEES STRONG 4TH QTR EARNINGS', 'BONUS WHEAT FLOUR FOR NORTH YEMEN  -- USDA', 'CREDIT CARD DISCLOSURE BILLS INTRODUCED', 'HUGHES CAPITAL UNIT SIGNS PACT WITH BEAR STEARNS', 'MAGMA LOWERS COPPER 0.75 CENT TO 66 CTS', 'BROWN-FORMAN <BFDB> SETS STOCK SPLIT, UPS PAYOUT', 'ESQUIRE RADIO AND ELECTRONICS INC <EE> 4TH QTR', 'SHEARSON LEHMAN NAMES NEW MANAGING DIRECTOR', 'BANKERS REPORT BREAKTHROUGH ON VENEZUELAN DEBT', 'UNITED PRESIDENTIAL CORP <UPCO> 4TH QTR NET', "TOWER REPORT DIMINISHES REAGAN'S HOPES OF REBOUND", 'JANUARY HOUSING SALES DROP, REALTY GROUP SAYS', 'ASSETS OF MONEY MARKET MUTUAL FUNDS ROSE 720.4 MLN DLRS IN LATEST WEEK\n', 'U.S. TAX WRITERS SEEK ESTATE TAX CURBS, RAISING 6.7 BILLION DLRS THRU 1991\n', 'SENATORS INTRODUCE EXPORT LICENSING REFORM BILL', 'EXCELAN INC SETS INITIAL STOCK OFFER', 'CCX NETWORK <CCXN> SECONDARY OFFERING UNDERWAY', 'FIRST UNION <FUNC> FILES 100 MLN DLR NOTES ISSUE', 'OWENS AND MINOR INC <OBOD> RAISES QTLY DIVIDEND', 'COMPUTER LANGUAGE RESEARCH IN <CLRI> 4TH QTR', '<CINRAM LTD> 4TH QTR NET', 'DU PONT CO <DD> LAUNCHES IMPROVED ARAMID FIBERS', 'STANDARD TRUSTCO SEES BETTER YEAR', 'HANDY AND HARMAN <HNH> 4TH QTR LOSS', 'ICO PRODUCERS TO PRESENT NEW COFFEE PROPOSAL', 'SHULTZ SAYS NO RESIGNATION OVER IRAN REPORT', "MCLEAN'S <MII> U.S. LINES SETS ASSET TRANSFER", 'CHEMLAWN <CHEM> RISES ON HOPES FOR HIGHER BIDS', 'U.S. SUGAR IMPORTS DOWN IN WEEK - USDA', 'BRAZIL ANTI-INFLATION PLAN LIMPS TO ANNIVERSARY', 'N.Z. OFFICIAL FOREIGN RESERVES FALL IN JANUARY', 'AGENCY REPORTS 39 SHIPS WAITING AT PANAMA CANAL', 'AMERICA FIRST MORTGAGE SETS SPECIAL PAYOUT', 'REPUBLICANS EYE BIGGER U.S. CONSERVATION RESERVE', 'ARVIN INDS <ARV> PROMOTES EVANS TO PRESIDENT', 'EMHART CORP <EMH> QTLY DIVIDEND', 'U.S. DATA POINT TO CAPITAL SPENDING SLOWDOWN', 'SENATORS INTRODUCE EXPORT LICENSING REFORM BILL', 'AM INTERNATIONAL <AM> CITES STRONG PROSPECTS', 'CCC CREDITS FOR HONDURAS SWITCHED TO WHITE CORN', 'ASSETS OF U.S. MONEY FUNDS ROSE IN WEEK', 'GULF BARGE FREIGHT RATES UP FURTHER ON CALL', 'ARGENTINA COULD SUSPEND DEBT PAYMENTS - DEPUTY', 'KEY U.S. TAX WRITERS SEEK ESTATE TAX CURBS', 'TREASURY BALANCES AT FED ROSE ON FEB 25', "CANADA'S WILSON SEEKS TEMPORARY BORROWING", 'GULF APPLIED <GATS> SELLS UNITS, SEES GAIN', 'FARMERS GROUP INC <FGRP> 4TH QTR NET', 'POTOMAC ELECTRIC POWER CO <POM> JAN NET', 'SPRINGBOARD <SPBD> IN DEAL', '<COFAB INC> BUYS GULFEX FOR UNDISCLOSED AMOUNT', 'U.S. WEEKLY SOYBEAN CRUSH 21,782,929 BUSHELS', 'SCHULT HOMES OFFERING PRICED AT FIVE DLRS/UNIT', 'TULTEX CORP <TTX> SETS QUARTERLY DIVIDEND', 'BURLINGTON <BUR>  GETS 30.5 MLN DLR CONTRACT', 'ROCKWELL <ROK> GETS 28.3 MLN DLR B-1 CONTRACT', 'ATICO FINANCIAL CORP <ATFC> 4TH QTR NET', 'ICO EXPORTERS TO MODIFY NEW PROPOSAL', 'U.S. COMMERCIAL PAPER FALLS 375 MLN DLRS IN FEB 18 WEEK, FED SAYS\n', 'N.Y. BUSINESS LOANS FALL 195 MLN DLRS IN FEB 18 WEEK, FED SAYS\n', 'NEW YORK BANK DISCOUNT WINDOW BORROWINGS 64 MLN DLRS IN FEB 25 WEEK\n', 'QUEBECOR <PQB> HEAD SEES NEW VENTURES LIKELY', 'NEW YORK BUSINESS LOANS FALL 195 MLN DLRS', 'N.Y. BANK DISCOUNT BORROWINGS 64 MLN DLRS', 'PHILIPPINE LONG DISTANCE <PHI> YEAR NET', 'LIBERTY ALL-STAR EQUITY FUND INITIAL DIV', 'COLUMBIA GAS SYSTEM INC <CG> REDEEMS DEBENTURES', 'COMBUSTION EN ...

# %%
#created a simple for loop to see all the titles and dates together
for i in docs: 
    info = i.title.text, i.date.text
    print(info)
len(info)
# Out:
# ('BAHIA COCOA REVIEW', '26-FEB-1987 15:01:01.79')
# ('STANDARD OIL <SRD> TO FORM FINANCIAL UNIT', '26-FEB-1987 15:02:20.00')
# ('TEXAS COMMERCE BANCSHARES <TCB> FILES PLAN', '26-FEB-1987 15:03:27.51')
# ('TALKING POINT/BANKAMERICA <BAC> EQUITY OFFER', '26-FEB-1987 15:07:13.72')
# ('NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE', '26-FEB-1987 15:10:44.60')
# ('ARGENTINE 1986/87 GRAIN/OILSEED REGISTRATIONS', '26-FEB-1987 15:14:36.41')
# ('RED LION INNS FILES PLANS OFFERING', '26-FEB-1987 15:14:42.83')
# ("USX <X> DEBT DOWGRADED BY MOODY'S", '26-FEB-1987 15:15:40.12')
# ('CHAMPION PRODUCTS <CH> APPROVES STOCK SPLIT', '26-FEB-1987 15:17:11.20')
# ('COMPUTER TERMINAL SYSTEMS <CPML> COMPLETES SALE', '26-FEB-1987 15:18:06.67')
# ('COBANCO INC <CBCO> YEAR NET', '26-FEB-1987 15:18:59.34')
# ('OHIO MATTRESS <OMT> MAY HAVE LOWER 1ST QTR NET', '26-FEB-1987 15:19:15.45')
# ('AM INTERNATIONAL INC <AM> 2ND QTR JAN 31', '26-FEB-1987 15:20:13.09')
# ('BROWN-FORMAN INC <BFD> 4TH QTR NET', '26-FEB-1987 15:20:27.17')
# ('NATIONAL INTERGROUP<NII> TO OFFER PERMIAN UNITS', '26-FEB-1987 15:20:48.43')
# ('ECONOMIC SPOTLIGHT - BANKAMERICA <BAC>', '26-FEB-1987 15:21:16.13')
# ('NATIONAL HEALTH ENHANCEMENT <NHES> NEW PROGRAM', '26-FEB-1987 15:24:48.56')
# ('DEAN FOODS <DF> SEES STRONG 4TH QTR EARNINGS', '26-FEB-1987 15:26:26.78')
# ('BONUS WHEAT FLOUR FOR NORTH YEMEN  -- USDA', '26-FEB-1987 15:26:54.12')
# ('CREDIT CARD DISCLOSURE BILLS INTRODUCED', '26-FEB-1987 15:32:03.12')
# ('HUGHES CAPITAL UNIT SIGNS PACT WITH BEAR STEARNS', '26-FEB-1987 15:33:23.61')
# ('MAGMA LOWERS COPPER 0.75 CENT TO 66 CTS', '26-FEB-1987 15:34:07.03')
# ('BROWN-FORMAN <BFDB> SETS STOCK SPLIT, UPS PAYOUT', '26-FEB-1987 15:34:16.30')
# ('ESQUIRE RADIO AND ELECTRONICS INC <EE> 4TH QTR', '26-FEB-1987 15:35:16.67')
# ('SHEARSON LEHMAN NAMES NEW MANAGING DIRECTOR', '26-FEB-1987 15:35:39.38')
# ('BANKERS REPORT BREAKTHROUGH ON VENEZUELAN DEBT', '26-FEB-1987 15:36:44.78')
# ('UNITED PRESIDENTIAL CORP <UPCO> 4TH QTR NET', '26-FEB-1987 15:36:53.42')
# ("TOWER REPORT DIMINISHES REAGAN'S HOPES OF REBOUND", '26-FEB-1987 15:38:26.23')
# ('JANUARY HOUSING SALES DROP, REALTY GROUP SAYS', '26-FEB-1987 15:39:41.92')
# ('ASSETS OF MONEY MARKET MUTUAL FUNDS ROSE 720.4 MLN DLRS IN LATEST WEEK\n', '26-FEB-1987 15:41:56.54')
# ('U.S. TAX WRITERS SEEK ESTATE TAX CURBS, RAISING 6.7 BILLION DLRS THRU 1991\n', '26-FEB-1987 15:43:14.36')
# ('SENATORS INTRODUCE EXPORT LICENSING REFORM BILL', '26-FEB-1987 15:43:59.53')
# ('EXCELAN INC SETS INITIAL STOCK OFFER', '26-FEB-1987 15:44:36.04')
# ('CCX NETWORK <CCXN> SECONDARY OFFERING UNDERWAY', '26-FEB-1987 15:45:19.65')
# ('FIRST UNION <FUNC> FILES 100 MLN DLR NOTES ISSUE', '26-FEB-1987 15:45:26.55')
# ('OWENS AND MINOR INC <OBOD> RAISES QTLY DIVIDEND', '26-FEB-1987 15:45:35.37')
# ('COMPUTER LANGUAGE RESEARCH IN <CLRI> 4TH QTR', '26-FEB-1987 15:45:39.20')
# ('<CINRAM LTD> 4TH QTR NET', '26-FEB-1987 15:45:47.29')
# ('DU PONT CO <DD> LAUNCHES IMPROVED ARAMID FIBERS', '26-FEB-1987 15:46:36.16')
# ('STANDARD TRUSTCO SEES BETTER YEAR', '26-FEB-1987 15:47:16.17')
# ('HANDY AND HARMAN <HNH> 4TH QTR LOSS', '26-FEB-1987 15:48:26.92')
# ('ICO PRODUCERS TO PRESENT NEW COFFEE PROPOSAL', '26-FEB-1987 15:49:27.16')
# ('SHULTZ SAYS NO RESIGNATION OVER IRAN REPORT', '26-FEB-1987 15:49:44.93')
# ("MCLEAN'S <MII> U.S. LINES SETS ASSET TRANSFER", '26-FEB-1987 15:49:56.01')
# ('CHEMLAWN <CHEM> RISES ON HOPES FOR HIGHER BIDS', '26-FEB-1987 15:51:17.84')
# ('U.S. SUGAR IMPORTS DOWN IN WEEK - USDA', '26-FEB-1987 15:51:28.42')
# ('BRAZIL ANTI-INFLATION PLAN LIMPS TO ANNIVERSARY', '26-FEB-1987 15:51:51.24')
# ('N.Z. OFFICIAL FOREIGN RESERVES FALL IN JANUARY', '26-FEB-1987 15:52:15.10')
# ('AGENCY REPORTS 39 SHIPS WAITING AT PANAMA CANAL', '26-FEB-1987 15:52:25.60')
# ('AMERICA FIRST MORTGAGE SETS SPECIAL PAYOUT', '26-FEB-1987 15:52:33.04')
# ('REPUBLICANS EYE BIGGER U.S. CONSERVATION RESERVE', '26-FEB-1987 15:52:57.49')
# ('ARVIN INDS <ARV> PROMOTES EVANS TO PRESIDENT', '26-FEB-1987 15:53:05.48')
# ('EMHART CORP <EMH> QTLY DIVIDEND', '26-FEB-1987 15:53:54.56')
# ('U.S. DATA POINT TO CAPITAL SPENDING SLOWDOWN', '26-FEB-1987 15:54:55.20')
# ('SENATORS INTRODUCE EXPORT LICENSING REFORM BILL', '26-FEB-1987 15:56:00.50')
# ('AM INTERNATIONAL <AM> CITES STRONG PROSPECTS', '26-FEB-1987 15:57:48.22')
# ('CCC CREDITS FOR HONDURAS SWITCHED TO WHITE CORN', '26-FEB-1987 15:58:07.34')
# ('ASSETS OF U.S. MONEY FUNDS ROSE IN WEEK', '26-FEB-1987 15:58:19.46')
# ('GULF BARGE FREIGHT RATES UP FURTHER ON CALL', '26-FEB-1987 15:58:47.73')
# ('ARGENTINA COULD SUSPEND DEBT PAYMENTS - DEPUTY', '26-FEB-1987 16:03:15.46')
# ('KEY U.S. TAX WRITERS SEEK ESTATE TAX CURBS', '26-FEB-1987 16:04:05.90')
# ('TREASURY BALANCES AT FED ROSE ON FEB 25', '26-FEB-1987 16:04:57.16')
# ("CANADA'S WILSON SEEKS TEMPORARY BORROWING", '26-FEB-1987 16:05:36.23')
# ('GULF APPLIED <GATS> SELLS UNITS, SEES GAIN', '26-FEB-1987 16:06:36.68')
# ('FARMERS GROUP INC <FGRP> 4TH QTR NET', '26-FEB-1987 16:07:14.07')
# ('POTOMAC ELECTRIC POWER CO <POM> JAN NET', '26-FEB-1987 16:07:27.81')
# ('SPRINGBOARD <SPBD> IN DEAL', '26-FEB-1987 16:08:15.22')
# ('<COFAB INC> BUYS GULFEX FOR UNDISCLOSED AMOUNT', '26-FEB-1987 16:08:33.15')
# ('U.S. WEEKLY SOYBEAN CRUSH 21,782,929 BUSHELS', '26-FEB-1987 16:10:43.67')
# ('SCHULT HOMES OFFERING PRICED AT FIVE DLRS/UNIT', '26-FEB-1987 16:11:21.94')
# ('TULTEX CORP <TTX> SETS QUARTERLY DIVIDEND', '26-FEB-1987 16:12:01.46')
# ('BURLINGTON <BUR>  GETS 30.5 MLN DLR CONTRACT', '26-FEB-1987 16:13:04.20')
# ('ROCKWELL <ROK> GETS 28.3 MLN DLR B-1 CONTRACT', '26-FEB-1987 16:13:36.47')
# ('ATICO FINANCIAL CORP <ATFC> 4TH QTR NET', '26-FEB-1987 16:14:23.26')
# ('ICO EXPORTERS TO MODIFY NEW PROPOSAL', '26-FEB-1987 16:15:51.34')
# ('U.S. COMMERCIAL PAPER FALLS 375 MLN DLRS IN FEB 18 WEEK, FED SAYS\n', '26-FEB-1987 16:16:52.92')
# ('N.Y. BUSINESS LOANS FALL 195 MLN DLRS IN FEB 18 WEEK, FED SAYS\n', '26-FEB-1987 16:17:05.96')
# ('NEW YORK BANK DISCOUNT WINDOW BORROWINGS 64 MLN DLRS IN FEB 25 WEEK\n', '26-FEB-1987 16:17:21.41')
# ('QUEBECOR <PQB> HEAD SEES NEW VENTURES LIKELY', '26-FEB-1987 16:18:41.47')
# ('NEW YORK BUSINESS LOANS FALL 195 MLN DLRS', '26-FEB-1987 16:20:06.60')
# ('N.Y. BANK DISCOUNT BORROWINGS 64 MLN DLRS', '26-FEB-1987 16:20:50.93')
# ('PHILIPPINE LONG DISTANCE <PHI> YEAR NET', '26-FEB-1987 16:23:47.79')
# ('LIBERTY ALL-STAR EQUITY FUND INITIAL DIV', '26-FEB-1987 16:25:23.18')
# ('COLUMBIA GAS SYSTEM INC <CG> REDEEMS DEBENTURES', '26-FEB-1987 16:25:42.65')
# ('COMBUSTION ENGINEERING INC <CSP> REGULAR DIV', '26-FEB-1987 16:26:09.46')
# ('TONKA CORP <TKA> RAISES DIVIDEND', '26-FEB-1987 16:27:07.38')
# ('BDM INTERNATIONAL <BDM> INCREASES QTRLY DIVS', '26-FEB-1987 16:29:15.25')
# ('SORG <SRG> STOCKHOLDERS FORM GROUP', '26-FEB-1987 16:29:19.68')
# ('SYSTEMATICS INC <SYST> REGULAR PAYOUT', '26-FEB-1987 16:29:26.29')
# ('TEXAS INSTRUMENTS <TXN> DEVELOPS NEW CHIP', '26-FEB-1987 16:29:30.05')
# ('CONSOLIDATED GAS <CNG>UNIT SAYS NO RULES BROKEN', '26-FEB-1987 16:29:56.33')
# ('U.S. M-1 MONEY SUPPLY RISES 2.1 BILLION DLRS IN FEB 16 WEEK, FED SAYS\n', '26-FEB-1987 16:31:34.18')
# ('<IVACO INC> YEAR NET', '26-FEB-1987 16:31:44.49')
# ('U.S. BANK DISCOUNT BORROWINGS AVERAGE 310 MLN DLRS IN FEB 25 WEEK, FED SAYS\n', '26-FEB-1987 16:31:54.04')
# ('U.S. BANK NET FREE RESERVES 644 MLN DLRS IN TWO WEEKS TO FEB 25, FED SAYS\n', '26-FEB-1987 16:32:04.32')
# ('INVESTMENT FIRMS CUT CYCLOPS <CYL> STAKE', '26-FEB-1987 16:32:37.30')
# ('ASCS TERMINAL MARKET VALUES FOR PIK GRAIN', '26-FEB-1987 16:32:51.69')
# ('CORADIAN CORP <CDIN> 4TH QTR NET', '26-FEB-1987 16:33:15.81')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17200/1986597453.py in <module>
#       1 #created a simple for loop to see all the titles and dates together
#       2 for i in docs:
# ----> 3     info = i.title.text, i.date.text
#       4     print(info)
#       5 len(info)
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %% [markdown]
# ### Goal is to create a dataframe and do some analysis on the df
# ### Ultimate goal is to see if what the financial climate was during 1987 and if there was a correlation with the politics at that time

# %%
#needed to create a function to extract the titles, dates and body of the documents so I could create a df
titles = []
dates = []
texts = []


for i in range(0,len(docs)):
    if docs[i].body != None:
        titles.append(docs[i].title.text)
        dates.append(docs[i].date.text)
        texts.append(docs[i].body.text)

# %%
#df is created but further preprocessing still needs to be done
df = pd.DataFrame(list(zip(titles, dates, texts)), columns = ['Title','Date','Text'])
df.head()
# Out:
#                                               Title                     Date  \
# 0                                BAHIA COCOA REVIEW  26-FEB-1987 15:01:01.79
# 1         STANDARD OIL <SRD> TO FORM FINANCIAL UNIT  26-FEB-1987 15:02:20.00
# 2        TEXAS COMMERCE BANCSHARES <TCB> FILES PLAN  26-FEB-1987 15:03:27.51
# 3      TALKING POINT/BANKAMERICA <BAC> EQUITY OFFER  26-FEB-1987 15:07:13.72
# 4  NATIONAL AVERAGE PRICES FOR FARMER-OWNED RESERVE  26-FEB-1987 15:10:44.60
#
#                                                 Text
# 0  Showers continued throughout the week in\nthe ...
# 1  Standard Oil Co and BP North America\nInc said...
# 2  Texas Commerce Bancshares Inc's Texas\nCommerc...
# 3  BankAmerica Corp is not under\npressure to act...
# 4  The U.S. Agriculture Department\nreported the ...

# %% [markdown]
# df['Date'] = pd.to_datetime(df['Date']) # If your Date column is of the type object otherwise skip this
# date_range = str(df['Date'].dt.date.min()) + ' to ' +str(df['Date'].dt.date.max())

# %%
df['Text'][0]
# Out:
# 'Showers continued throughout the week in\nthe Bahia cocoa zone, alleviating the drought since early\nJanuary and improving prospects for the coming temporao,\nalthough normal humidity levels have not been restored,\nComissaria Smith said in its weekly review.\n    The dry period means the temporao will be late this year.\n    Arrivals for the week ended February 22 were 155,221 bags\nof 60 kilos making a cumulative total for the season of 5.93\nmln against 5.81 at the same stage last year. Again it seems\nthat cocoa delivered earlier on consignment was included in the\narrivals figures.\n    Comissaria Smith said there is still some doubt as to how\nmuch old crop cocoa is still available as harvesting has\npractically come to an end. With total Bahia crop estimates\naround 6.4 mln bags and sales standing at almost 6.2 mln there\nare a few hundred thousand bags still in the hands of farmers,\nmiddlemen, exporters and processors.\n    There are doubts as to how much of this cocoa would be fit\nfor export as shippers are now experiencing dificulties in\nobtaining +Bahia superior+ certificates.\n    In view of the lower quality over recent weeks farmers have\nsold a good part of their cocoa held on consignment.\n    Comissaria Smith said spot bean prices rose to 340 to 350\ncruzados per arroba of 15 kilos.\n    Bean shippers were reluctant to offer nearby shipment and\nonly limited sales were booked for March shipment at 1,750 to\n1,780 dlrs per tonne to ports to be named.\n    New crop sales were also light and all to open ports with\nJune/July going at 1,850 and 1,880 dlrs and at 35 and 45 dlrs\nunder New York july, Aug/Sept at 1,870, 1,875 and 1,880 dlrs\nper tonne FOB.\n    Routine sales of butter were made. March/April sold at\n4,340, 4,345 and 4,350 dlrs.\n    April/May butter went at 2.27 times New York May, June/July\nat 4,400 and 4,415 dlrs, Aug/Sept at 4,351 to 4,450 dlrs and at\n2.27 and 2.28 times New York Sept and Oct/Dec at 4,480 dlrs and\n2.27 times New York Dec, Comissaria Smith said.\n    Destinations were the U.S., Covertible currency areas,\nUruguay and open ports.\n    Cake sales were registered at 785 to 995 dlrs for\nMarch/April, 785 dlrs for May, 753 dlrs for Aug and 0.39 times\nNew York Dec for Oct/Dec.\n    Buyers were the U.S., Argentina, Uruguay and convertible\ncurrency areas.\n    Liquor sales were limited with March/April selling at 2,325\nand 2,380 dlrs, June/July at 2,375 dlrs and at 1.25 times New\nYork July, Aug/Sept at 2,400 dlrs and at 1.25 times New York\nSept and Oct/Dec at 1.25 times New York Dec, Comissaria Smith\nsaid.\n    Total Bahia sales are currently estimated at 6.13 mln bags\nagainst the 1986/87 crop and 1.06 mln bags against the 1987/88\ncrop.\n    Final figures for the period to February 28 are expected to\nbe published by the Brazilian Cocoa Trade Commission after\ncarnival which ends midday on February 27.\n Reuter\n\x03'

# %%
df.shape
# Out:
# (19043, 3)

# %%
df.tail()
# Out:
#                                                    Title  \
# 19038  JAPAN/INDIA CONFERENCE CUTS GULF WAR RISK CHARGES
# 19039      SOVIET INDUSTRIAL GROWTH/TRADE SLOWER IN 1987
# 19040     SIX KILLED IN SOUTH AFRICAN GOLD MINE ACCIDENT
# 19041   PROJECTIONS SHOW SWISS VOTERS WANT TRIED PARTIES
# 19042   AMERICAN EXCHANGE INTRODUCES INSTITUTIONAL INDEX
#
#                           Date  \
# 19038  19-OCT-1987 00:34:08.94
# 19039  19-OCT-1987 00:18:22.79
# 19040  19-OCT-1987 00:05:11.26
# 19041  19-OCT-1987 00:03:21.69
# 19042  19-OCT-1987 13:30:41.59
#
#                                                     Text
# 19038  The Japan/India-Pakistan-Gulf/Japan\nshipping ...
# 19039  The Soviet Union's industrial output is\ngrowi...
# 19040  Six black miners have been killed\nand two inj...
# 19041  The prospect of a dominant alliance of\nsocial...
# 19042  The American Stock Exchange said it has\nintro...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19043 entries, 0 to 19042
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Title   19043 non-null  object
#  1   Date    19043 non-null  object
#  2   Text    19043 non-null  object
# dtypes: object(3)
# memory usage: 446.4+ KB

# %%
df.describe()  #unique is sufficiently less than the total count. Consider removing
# Out:
#                                                  Title  \
# count                                            19043
# unique                                           18253
# top     PROPOSED OFFERINGS RECENTLY FILED WITH THE SEC
# freq                                                25
#
#                            Date  \
# count                     19043
# unique                    19043
# top     26-FEB-1987 15:01:01.79
# freq                          1
#
#                                                      Text
# count                                               19043
# unique                                              18781
# top     The Bundesbank left credit policies\nunchanged...
# freq                                                    4

# %% [markdown]
# ### Preprocessing the data

# %%
# will merge the individual text columns together into a single column
#df['all_text'] = df['Title'] + df['Text']
#marking down this bc the result does not contain a space inbetween the text and title

# %%
#convert all words to lowercase since python is case sensitive
#df['all_text']= df['all_text'].str.lower()

# %%
df['Text']= df['Text'].str.lower()

# %%
df['Title']= df['Title'].str.lower()

# %%
df['Title'].head()
# Out:
# 0                                  bahia cocoa review
# 1           standard oil <srd> to form financial unit
# 2          texas commerce bancshares <tcb> files plan
# 3        talking point/bankamerica <bac> equity offer
# 4    national average prices for farmer-owned reserve
# Name: Title, dtype: object

# %%
df['Text'].head()
# Out:
# 0    showers continued throughout the week in\nthe ...
# 1    standard oil co and bp north america\ninc said...
# 2    texas commerce bancshares inc's texas\ncommerc...
# 3    bankamerica corp is not under\npressure to act...
# 4    the u.s. agriculture department\nreported the ...
# Name: Text, dtype: object

# %%
#check to see if all lowercase
#df['all_text']

# %%
df.head()
# Out:
#                                               Title                     Date  \
# 0                                bahia cocoa review  26-FEB-1987 15:01:01.79
# 1         standard oil <srd> to form financial unit  26-FEB-1987 15:02:20.00
# 2        texas commerce bancshares <tcb> files plan  26-FEB-1987 15:03:27.51
# 3      talking point/bankamerica <bac> equity offer  26-FEB-1987 15:07:13.72
# 4  national average prices for farmer-owned reserve  26-FEB-1987 15:10:44.60
#
#                                                 Text
# 0  showers continued throughout the week in\nthe ...
# 1  standard oil co and bp north america\ninc said...
# 2  texas commerce bancshares inc's texas\ncommerc...
# 3  bankamerica corp is not under\npressure to act...
# 4  the u.s. agriculture department\nreported the ...

# %%
df['Text'][0]
# Out:
# 'showers continued throughout the week in\nthe bahia cocoa zone, alleviating the drought since early\njanuary and improving prospects for the coming temporao,\nalthough normal humidity levels have not been restored,\ncomissaria smith said in its weekly review.\n    the dry period means the temporao will be late this year.\n    arrivals for the week ended february 22 were 155,221 bags\nof 60 kilos making a cumulative total for the season of 5.93\nmln against 5.81 at the same stage last year. again it seems\nthat cocoa delivered earlier on consignment was included in the\narrivals figures.\n    comissaria smith said there is still some doubt as to how\nmuch old crop cocoa is still available as harvesting has\npractically come to an end. with total bahia crop estimates\naround 6.4 mln bags and sales standing at almost 6.2 mln there\nare a few hundred thousand bags still in the hands of farmers,\nmiddlemen, exporters and processors.\n    there are doubts as to how much of this cocoa would be fit\nfor export as shippers are now experiencing dificulties in\nobtaining +bahia superior+ certificates.\n    in view of the lower quality over recent weeks farmers have\nsold a good part of their cocoa held on consignment.\n    comissaria smith said spot bean prices rose to 340 to 350\ncruzados per arroba of 15 kilos.\n    bean shippers were reluctant to offer nearby shipment and\nonly limited sales were booked for march shipment at 1,750 to\n1,780 dlrs per tonne to ports to be named.\n    new crop sales were also light and all to open ports with\njune/july going at 1,850 and 1,880 dlrs and at 35 and 45 dlrs\nunder new york july, aug/sept at 1,870, 1,875 and 1,880 dlrs\nper tonne fob.\n    routine sales of butter were made. march/april sold at\n4,340, 4,345 and 4,350 dlrs.\n    april/may butter went at 2.27 times new york may, june/july\nat 4,400 and 4,415 dlrs, aug/sept at 4,351 to 4,450 dlrs and at\n2.27 and 2.28 times new york sept and oct/dec at 4,480 dlrs and\n2.27 times new york dec, comissaria smith said.\n    destinations were the u.s., covertible currency areas,\nuruguay and open ports.\n    cake sales were registered at 785 to 995 dlrs for\nmarch/april, 785 dlrs for may, 753 dlrs for aug and 0.39 times\nnew york dec for oct/dec.\n    buyers were the u.s., argentina, uruguay and convertible\ncurrency areas.\n    liquor sales were limited with march/april selling at 2,325\nand 2,380 dlrs, june/july at 2,375 dlrs and at 1.25 times new\nyork july, aug/sept at 2,400 dlrs and at 1.25 times new york\nsept and oct/dec at 1.25 times new york dec, comissaria smith\nsaid.\n    total bahia sales are currently estimated at 6.13 mln bags\nagainst the 1986/87 crop and 1.06 mln bags against the 1987/88\ncrop.\n    final figures for the period to february 28 are expected to\nbe published by the brazilian cocoa trade commission after\ncarnival which ends midday on february 27.\n reuter\n\x03'

# %%
df['Title'] =df['Title'].replace('\n', ' ', regex=True)

# %%
#checked results and it is fine
df['Title'][0]
# Out:
# 'bahia cocoa review'

# %%
#I noticed that the new line \n was still in the df, therefore need to remove
df['Text'] =df['Text'].replace('\n', ' ', regex=True)

# %%
#checked results and it is fine
df['Text'][0]
# Out:
# 'showers continued throughout the week in the bahia cocoa zone, alleviating the drought since early january and improving prospects for the coming temporao, although normal humidity levels have not been restored, comissaria smith said in its weekly review.     the dry period means the temporao will be late this year.     arrivals for the week ended february 22 were 155,221 bags of 60 kilos making a cumulative total for the season of 5.93 mln against 5.81 at the same stage last year. again it seems that cocoa delivered earlier on consignment was included in the arrivals figures.     comissaria smith said there is still some doubt as to how much old crop cocoa is still available as harvesting has practically come to an end. with total bahia crop estimates around 6.4 mln bags and sales standing at almost 6.2 mln there are a few hundred thousand bags still in the hands of farmers, middlemen, exporters and processors.     there are doubts as to how much of this cocoa would be fit for export as shippers are now experiencing dificulties in obtaining +bahia superior+ certificates.     in view of the lower quality over recent weeks farmers have sold a good part of their cocoa held on consignment.     comissaria smith said spot bean prices rose to 340 to 350 cruzados per arroba of 15 kilos.     bean shippers were reluctant to offer nearby shipment and only limited sales were booked for march shipment at 1,750 to 1,780 dlrs per tonne to ports to be named.     new crop sales were also light and all to open ports with june/july going at 1,850 and 1,880 dlrs and at 35 and 45 dlrs under new york july, aug/sept at 1,870, 1,875 and 1,880 dlrs per tonne fob.     routine sales of butter were made. march/april sold at 4,340, 4,345 and 4,350 dlrs.     april/may butter went at 2.27 times new york may, june/july at 4,400 and 4,415 dlrs, aug/sept at 4,351 to 4,450 dlrs and at 2.27 and 2.28 times new york sept and oct/dec at 4,480 dlrs and 2.27 times new york dec, comissaria smith said.     destinations were the u.s., covertible currency areas, uruguay and open ports.     cake sales were registered at 785 to 995 dlrs for march/april, 785 dlrs for may, 753 dlrs for aug and 0.39 times new york dec for oct/dec.     buyers were the u.s., argentina, uruguay and convertible currency areas.     liquor sales were limited with march/april selling at 2,325 and 2,380 dlrs, june/july at 2,375 dlrs and at 1.25 times new york july, aug/sept at 2,400 dlrs and at 1.25 times new york sept and oct/dec at 1.25 times new york dec, comissaria smith said.     total bahia sales are currently estimated at 6.13 mln bags against the 1986/87 crop and 1.06 mln bags against the 1987/88 crop.     final figures for the period to february 28 are expected to be published by the brazilian cocoa trade commission after carnival which ends midday on february 27.  reuter \x03'

# %%
import string
punctuation = string.punctuation
df['Text'] = df['Text'].apply(lambda x: [word for word in x if word not in punctuation])

# %%
df['Title'] = df['Title'].apply(lambda x: [word for word in x if word not in punctuation])

# %%
df["Text"].head()
# Out:
# 0    [s, h, o, w, e, r, s,  , c, o, n, t, i, n, u, ...
# 1    [s, t, a, n, d, a, r, d,  , o, i, l,  , c, o, ...
# 2    [t, e, x, a, s,  , c, o, m, m, e, r, c, e,  , ...
# 3    [b, a, n, k, a, m, e, r, i, c, a,  , c, o, r, ...
# 4    [t, h, e,  , u, s,  , a, g, r, i, c, u, l, t, ...
# Name: Text, dtype: object

# %%
df["Title"].head()
# Out:
# 0    [b, a, h, i, a,  , c, o, c, o, a,  , r, e, v, ...
# 1    [s, t, a, n, d, a, r, d,  , o, i, l,  , s, r, ...
# 2    [t, e, x, a, s,  , c, o, m, m, e, r, c, e,  , ...
# 3    [t, a, l, k, i, n, g,  , p, o, i, n, t, b, a, ...
# 4    [n, a, t, i, o, n, a, l,  , a, v, e, r, a, g, ...
# Name: Title, dtype: object

# %%
import nltk

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\faria\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
df['Text'].apply(word_tokenize)

# %%
df['Title'].apply(word_tokenize)

# %%
#this function will tokenize a panda col (which here I merged) and return lists of token
#df['tokenized'] = df.apply(lambda x: tokenize(x['Text']), axis=1)

# %%
# now remove stopwords-they add little value to the meaning and therfore reduces noise
nltk.download('stopwords');
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\faria\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk.corpus import stopwords
sw_nltk = stopwords.words('english')
print(sw_nltk)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
def remove_stopwords(tokenized_column):
    """Return a list of tokens with English stopwords removed. 

    Args:
        column: Pandas dataframe column of tokenized data from tokenize()

    Returns:
        tokens (list): Tokenized list with stopwords removed.

    """
    stops = set(stopwords.words("english"))
    return [word for word in tokenized_column if not word in stops]

# %%
import pandas as pd
from textblob import TextBlob
import numpy as np
import os
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\faria\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['Text'] = df['Text'].apply(lambda x: [item for item in x.split() if item not in stop])

# %%
df['Title'] = df['Title'].apply(lambda x: [item for item in x.split() if item not in stop])

# %%
df['Title'][0]
# Out:
# ['bahia', 'cocoa', 'review']

# %%
df['Text'][0]
# Out:
# ['showers',
#  'continued',
#  'throughout',
#  'week',
#  'bahia',
#  'cocoa',
#  'zone,',
#  'alleviating',
#  'drought',
#  'since',
#  'early',
#  'january',
#  'improving',
#  'prospects',
#  'coming',
#  'temporao,',
#  'although',
#  'normal',
#  'humidity',
#  'levels',
#  'restored,',
#  'comissaria',
#  'smith',
#  'said',
#  'weekly',
#  'review.',
#  'dry',
#  'period',
#  'means',
#  'temporao',
#  'late',
#  'year.',
#  'arrivals',
#  'week',
#  'ended',
#  'february',
#  '22',
#  '155,221',
#  'bags',
#  '60',
#  'kilos',
#  'making',
#  'cumulative',
#  'total',
#  'season',
#  '5.93',
#  'mln',
#  '5.81',
#  'stage',
#  'last',
#  'year.',
#  'seems',
#  'cocoa',
#  'delivered',
#  'earlier',
#  'consignment',
#  'included',
#  'arrivals',
#  'figures.',
#  'comissaria',
#  'smith',
#  'said',
#  'still',
#  'doubt',
#  'much',
#  'old',
#  'crop',
#  'cocoa',
#  'still',
#  'available',
#  'harvesting',
#  'practically',
#  'come',
#  'end.',
#  'total',
#  'bahia',
#  'crop',
#  'estimates',
#  'around',
#  '6.4',
#  'mln',
#  'bags',
#  'sales',
#  'standing',
#  'almost',
#  '6.2',
#  'mln',
#  'hundred',
#  'thousand',
#  'bags',
#  'still',
#  'hands',
#  'farmers,',
#  'middlemen,',
#  'exporters',
#  'processors.',
#  'doubts',
#  'much',
#  'cocoa',
#  'would',
#  'fit',
#  'export',
#  'shippers',
#  'experiencing',
#  'dificulties',
#  'obtaining',
#  '+bahia',
#  'superior+',
#  'certificates.',
#  'view',
#  'lower',
#  'quality',
#  'recent',
#  'weeks',
#  'farmers',
#  'sold',
#  'good',
#  'part',
#  'cocoa',
#  'held',
#  'consignment.',
#  'comissaria',
#  'smith',
#  'said',
#  'spot',
#  'bean',
#  'prices',
#  'rose',
#  '340',
#  '350',
#  'cruzados',
#  'per',
#  'arroba',
#  '15',
#  'kilos.',
#  'bean',
#  'shippers',
#  'reluctant',
#  'offer',
#  'nearby',
#  'shipment',
#  'limited',
#  'sales',
#  'booked',
#  'march',
#  'shipment',
#  '1,750',
#  '1,780',
#  'dlrs',
#  'per',
#  'tonne',
#  'ports',
#  'named.',
#  'new',
#  'crop',
#  'sales',
#  'also',
#  'light',
#  'open',
#  'ports',
#  'june/july',
#  'going',
#  '1,850',
#  '1,880',
#  'dlrs',
#  '35',
#  '45',
#  'dlrs',
#  'new',
#  'york',
#  'july,',
#  'aug/sept',
#  '1,870,',
#  '1,875',
#  '1,880',
#  'dlrs',
#  'per',
#  'tonne',
#  'fob.',
#  'routine',
#  'sales',
#  'butter',
#  'made.',
#  'march/april',
#  'sold',
#  '4,340,',
#  '4,345',
#  '4,350',
#  'dlrs.',
#  'april/may',
#  'butter',
#  'went',
#  '2.27',
#  'times',
#  'new',
#  'york',
#  'may,',
#  'june/july',
#  '4,400',
#  '4,415',
#  'dlrs,',
#  'aug/sept',
#  '4,351',
#  '4,450',
#  'dlrs',
#  '2.27',
#  '2.28',
#  'times',
#  'new',
#  'york',
#  'sept',
#  'oct/dec',
#  '4,480',
#  'dlrs',
#  '2.27',
#  'times',
#  'new',
#  'york',
#  'dec,',
#  'comissaria',
#  'smith',
#  'said.',
#  'destinations',
#  'u.s.,',
#  'covertible',
#  'currency',
#  'areas,',
#  'uruguay',
#  'open',
#  'ports.',
#  'cake',
#  'sales',
#  'registered',
#  '785',
#  '995',
#  'dlrs',
#  'march/april,',
#  '785',
#  'dlrs',
#  'may,',
#  '753',
#  'dlrs',
#  'aug',
#  '0.39',
#  'times',
#  'new',
#  'york',
#  'dec',
#  'oct/dec.',
#  'buyers',
#  'u.s.,',
#  'argentina,',
#  'uruguay',
#  'convertible',
#  'currency',
#  'areas.',
#  'liquor',
#  'sales',
#  'limited',
#  'march/april',
#  'selling',
#  '2,325',
#  '2,380',
#  'dlrs,',
#  'june/july',
#  '2,375',
#  'dlrs',
#  '1.25',
#  'times',
#  'new',
#  'york',
#  'july,',
#  'aug/sept',
#  '2,400',
#  'dlrs',
#  '1.25',
#  'times',
#  'new',
#  'york',
#  'sept',
#  'oct/dec',
#  '1.25',
#  'times',
#  'new',
#  'york',
#  'dec,',
#  'comissaria',
#  'smith',
#  'said.',
#  'total',
#  'bahia',
#  'sales',
#  'currently',
#  'estimated',
#  '6.13',
#  'mln',
#  'bags',
#  '1986/87',
#  'crop',
#  '1.06',
#  'mln',
#  'bags',
#  '1987/88',
#  'crop.',
#  'final',
#  'figures',
#  'period',
#  'february',
#  '28',
#  'expected',
#  'published',
#  'brazilian',
#  'cocoa',
#  'trade',
#  'commission',
#  'carnival',
#  'ends',
#  'midday',
#  'february',
#  '27.',
#  'reuter',
#  '\x03']

# %%
import pandas as pd
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# %%
#now i need to stem or lemmatize the strings- chose lemmatize because it is more accurate and
#using stem produced a stem of the word financial that excluded it from my like words of money
lmtzr = WordNetLemmatizer()
df['Lem_text'] = df['Text'].apply(
                    lambda lst:[lmtzr.lemmatize(word) for word in lst])

# %%
df['Lem_title'] = df['Title'].apply(
                    lambda lst:[lmtzr.lemmatize(word) for word in lst])

# %%
#appears correct
df['Lem_text'][0]
# Out:
# ['shower',
#  'continued',
#  'throughout',
#  'week',
#  'bahia',
#  'cocoa',
#  'zone,',
#  'alleviating',
#  'drought',
#  'since',
#  'early',
#  'january',
#  'improving',
#  'prospect',
#  'coming',
#  'temporao,',
#  'although',
#  'normal',
#  'humidity',
#  'level',
#  'restored,',
#  'comissaria',
#  'smith',
#  'said',
#  'weekly',
#  'review.',
#  'dry',
#  'period',
#  'mean',
#  'temporao',
#  'late',
#  'year.',
#  'arrival',
#  'week',
#  'ended',
#  'february',
#  '22',
#  '155,221',
#  'bag',
#  '60',
#  'kilo',
#  'making',
#  'cumulative',
#  'total',
#  'season',
#  '5.93',
#  'mln',
#  '5.81',
#  'stage',
#  'last',
#  'year.',
#  'seems',
#  'cocoa',
#  'delivered',
#  'earlier',
#  'consignment',
#  'included',
#  'arrival',
#  'figures.',
#  'comissaria',
#  'smith',
#  'said',
#  'still',
#  'doubt',
#  'much',
#  'old',
#  'crop',
#  'cocoa',
#  'still',
#  'available',
#  'harvesting',
#  'practically',
#  'come',
#  'end.',
#  'total',
#  'bahia',
#  'crop',
#  'estimate',
#  'around',
#  '6.4',
#  'mln',
#  'bag',
#  'sale',
#  'standing',
#  'almost',
#  '6.2',
#  'mln',
#  'hundred',
#  'thousand',
#  'bag',
#  'still',
#  'hand',
#  'farmers,',
#  'middlemen,',
#  'exporter',
#  'processors.',
#  'doubt',
#  'much',
#  'cocoa',
#  'would',
#  'fit',
#  'export',
#  'shipper',
#  'experiencing',
#  'dificulties',
#  'obtaining',
#  '+bahia',
#  'superior+',
#  'certificates.',
#  'view',
#  'lower',
#  'quality',
#  'recent',
#  'week',
#  'farmer',
#  'sold',
#  'good',
#  'part',
#  'cocoa',
#  'held',
#  'consignment.',
#  'comissaria',
#  'smith',
#  'said',
#  'spot',
#  'bean',
#  'price',
#  'rose',
#  '340',
#  '350',
#  'cruzados',
#  'per',
#  'arroba',
#  '15',
#  'kilos.',
#  'bean',
#  'shipper',
#  'reluctant',
#  'offer',
#  'nearby',
#  'shipment',
#  'limited',
#  'sale',
#  'booked',
#  'march',
#  'shipment',
#  '1,750',
#  '1,780',
#  'dlrs',
#  'per',
#  'tonne',
#  'port',
#  'named.',
#  'new',
#  'crop',
#  'sale',
#  'also',
#  'light',
#  'open',
#  'port',
#  'june/july',
#  'going',
#  '1,850',
#  '1,880',
#  'dlrs',
#  '35',
#  '45',
#  'dlrs',
#  'new',
#  'york',
#  'july,',
#  'aug/sept',
#  '1,870,',
#  '1,875',
#  '1,880',
#  'dlrs',
#  'per',
#  'tonne',
#  'fob.',
#  'routine',
#  'sale',
#  'butter',
#  'made.',
#  'march/april',
#  'sold',
#  '4,340,',
#  '4,345',
#  '4,350',
#  'dlrs.',
#  'april/may',
#  'butter',
#  'went',
#  '2.27',
#  'time',
#  'new',
#  'york',
#  'may,',
#  'june/july',
#  '4,400',
#  '4,415',
#  'dlrs,',
#  'aug/sept',
#  '4,351',
#  '4,450',
#  'dlrs',
#  '2.27',
#  '2.28',
#  'time',
#  'new',
#  'york',
#  'sept',
#  'oct/dec',
#  '4,480',
#  'dlrs',
#  '2.27',
#  'time',
#  'new',
#  'york',
#  'dec,',
#  'comissaria',
#  'smith',
#  'said.',
#  'destination',
#  'u.s.,',
#  'covertible',
#  'currency',
#  'areas,',
#  'uruguay',
#  'open',
#  'ports.',
#  'cake',
#  'sale',
#  'registered',
#  '785',
#  '995',
#  'dlrs',
#  'march/april,',
#  '785',
#  'dlrs',
#  'may,',
#  '753',
#  'dlrs',
#  'aug',
#  '0.39',
#  'time',
#  'new',
#  'york',
#  'dec',
#  'oct/dec.',
#  'buyer',
#  'u.s.,',
#  'argentina,',
#  'uruguay',
#  'convertible',
#  'currency',
#  'areas.',
#  'liquor',
#  'sale',
#  'limited',
#  'march/april',
#  'selling',
#  '2,325',
#  '2,380',
#  'dlrs,',
#  'june/july',
#  '2,375',
#  'dlrs',
#  '1.25',
#  'time',
#  'new',
#  'york',
#  'july,',
#  'aug/sept',
#  '2,400',
#  'dlrs',
#  '1.25',
#  'time',
#  'new',
#  'york',
#  'sept',
#  'oct/dec',
#  '1.25',
#  'time',
#  'new',
#  'york',
#  'dec,',
#  'comissaria',
#  'smith',
#  'said.',
#  'total',
#  'bahia',
#  'sale',
#  'currently',
#  'estimated',
#  '6.13',
#  'mln',
#  'bag',
#  '1986/87',
#  'crop',
#  '1.06',
#  'mln',
#  'bag',
#  '1987/88',
#  'crop.',
#  'final',
#  'figure',
#  'period',
#  'february',
#  '28',
#  'expected',
#  'published',
#  'brazilian',
#  'cocoa',
#  'trade',
#  'commission',
#  'carnival',
#  'end',
#  'midday',
#  'february',
#  '27.',
#  'reuter',
#  '\x03']

# %%
data = df[['Lem_title','Date', 'Lem_text']]

# %%
data.head()
# Out:
#                                            Lem_title                     Date  \
# 0                             [bahia, cocoa, review]  26-FEB-1987 15:01:01.79
# 1      [standard, oil, <srd>, form, financial, unit]  26-FEB-1987 15:02:20.00
# 2   [texas, commerce, bancshares, <tcb>, file, plan]  26-FEB-1987 15:03:27.51
# 3  [talking, point/bankamerica, <bac>, equity, of...  26-FEB-1987 15:07:13.72
# 4  [national, average, price, farmer-owned, reserve]  26-FEB-1987 15:10:44.60
#
#                                             Lem_text
# 0  [shower, continued, throughout, week, bahia, c...
# 1  [standard, oil, co, bp, north, america, inc, s...
# 2  [texas, commerce, bancshares, inc's, texas, co...
# 3  [bankamerica, corp, pressure, act, quickly, pr...
# 4  [u.s., agriculture, department, reported, farm...

# %% [markdown]
# df_money.head()

# %% [markdown]
# filtered_df =df[df['lemmatize_text'].str.contains('money', regex=False)]

# %%
#initially I started with the word money, but after applying synset (see below I realized that fund was the most inclusive)
#filt_df = data[data['Lem_title'].str.contains('money', regex=False)]

# %%
filt_df.shape  # I want to first see the titles with money
# Out:
# (224, 3)

# %%
filt_df = data[data['Lem_title'].str.contains('fund', regex=False)]

# %%
filt_df.shape #more titles exist with the word money, here I ran it with fund
# Out:
# (106, 3)

# %%
filt_df = data[data['Lem_title'].str.contains('fund', regex=False)]

# %%
filt_df = data[data['Lem_text'].str.contains('fund', regex=False)]

# %%
filt_df.head()
# Out:
#                                              Lem_title  \
# 47    [america, first, mortgage, set, special, payout]
# 55              [asset, u.s., money, fund, rose, week]
# 78   [columbia, gas, system, inc, <cg>, redeems, de...
# 96   [u.s., bank, discount, borrowing, 310, mln, dlrs]
# 100   [liberty, all-star, <usa>, set, initial, payout]
#
#                         Date  \
# 47   26-FEB-1987 15:52:33.04
# 55   26-FEB-1987 15:58:19.46
# 78   26-FEB-1987 16:25:42.65
# 96   26-FEB-1987 16:41:34.44
# 100  26-FEB-1987 16:45:44.50
#
#                                               Lem_text
# 47   [<america, first, federally, guaranteed, mortg...
# 55   [asset, money, market, mutual, fund, increased...
# 78   [columbia, gas, system, inc, said, redeem, 4.7...
# 96   [u.s., bank, discount, window, borrowing, le, ...
# 100  [liberty, all-star, equity, fund, said, declar...

# %%
filt_df.shape  #by changing the word from math to fund, I increased the rows by over 300
# Out:
# (1028, 3)

# %%
filt_df['Lem_text'][96]  #testing
# Out:
# ['u.s.',
#  'bank',
#  'discount',
#  'window',
#  'borrowing',
#  'le',
#  'extended',
#  'credit',
#  'averaged',
#  '310',
#  'mln',
#  'dlrs',
#  'week',
#  'wednesday',
#  'february',
#  '25,',
#  'federal',
#  'reserve',
#  'said.',
#  'fed',
#  'said',
#  'overall',
#  'borrowing',
#  'week',
#  'fell',
#  '131',
#  'mln',
#  'dlrs',
#  '614',
#  'mln',
#  'dlrs,',
#  'extended',
#  'credit',
#  '10',
#  'mln',
#  'dlrs',
#  '304',
#  'mln',
#  'dlrs.',
#  'week',
#  'second',
#  'half',
#  'two-week',
#  'statement',
#  'period.',
#  'net',
#  'borrowing',
#  'prior',
#  'week',
#  'averaged',
#  '451',
#  'mln',
#  'dlrs.',
#  'commenting',
#  'two-week',
#  'statement',
#  'period',
#  'ended',
#  'february',
#  '25,',
#  'fed',
#  'said',
#  'bank',
#  'average',
#  'net',
#  'free',
#  'reserve',
#  '644',
#  'mln',
#  'dlrs',
#  'day,',
#  '1.34',
#  'billion',
#  'two',
#  'week',
#  'earlier.',
#  'federal',
#  'reserve',
#  'spokesman',
#  'told',
#  'press',
#  'briefing',
#  'large',
#  'single',
#  'day',
#  'net',
#  'miss',
#  "fed's",
#  'reserve',
#  'projection',
#  'week',
#  'wednesday.',
#  'said',
#  'natural',
#  'float',
#  '"acting',
#  'bit',
#  'strangely"',
#  'time',
#  'year,',
#  'noting',
#  'poor',
#  'weather',
#  'latest',
#  'week.',
#  'spokesman',
#  'said',
#  'natural',
#  'float',
#  'ranged',
#  '500',
#  'mln',
#  'dlrs',
#  'friday,',
#  'could',
#  'give',
#  'reason,',
#  'nearly',
#  'one',
#  'billion',
#  'dlrs',
#  'thursday',
#  'wednesday.',
#  'fed',
#  'spokeman',
#  'could',
#  'give',
#  'reason',
#  "thursday's",
#  'high',
#  'float,',
#  'said',
#  '750',
#  'mln',
#  'dlrs',
#  "wednesday's",
#  'float',
#  'figure',
#  'due',
#  'holdover',
#  'transportation',
#  'float',
#  'two',
#  'widely',
#  'separated',
#  'fed',
#  'districts.',
#  'week',
#  'whole,',
#  'said',
#  'float',
#  'related',
#  'adjustment',
#  '"small,"',
#  'adding',
#  'fell',
#  'negative',
#  '750',
#  'mln',
#  'dlrs',
#  'tuesday',
#  'due',
#  'number',
#  'correction',
#  'unrelated',
#  'cash',
#  'letter',
#  'error',
#  'six',
#  'district',
#  'around',
#  'country.',
#  'spokesman',
#  'said',
#  'tuesday',
#  'wednesday,',
#  'two',
#  'different',
#  'clearing',
#  'bank',
#  'system',
#  'problem',
#  'security',
#  'federal',
#  'fund',
#  'wire',
#  'held',
#  'open',
#  '2000',
#  '2100',
#  'est',
#  'days.',
#  'however,',
#  'said',
#  'problem',
#  'cleared',
#  'afternoon',
#  'evidence',
#  'reserve',
#  'impact.',
#  'week',
#  'ended',
#  'wednesday,',
#  '45',
#  'pct',
#  'net',
#  'discount',
#  'window',
#  'borrowing',
#  'made',
#  'smallest',
#  'banks,',
#  '30',
#  'pct',
#  '14',
#  'large',
#  'money',
#  'center',
#  'bank',
#  '25',
#  'pct',
#  'large',
#  'regional',
#  'institutions.',
#  'wednesday,',
#  '55',
#  'pct',
#  'borrowing',
#  'accounted',
#  'money',
#  'center',
#  'banks,',
#  '30',
#  'pct',
#  'large',
#  'regionals',
#  '15',
#  'pct',
#  'smallest',
#  'banks.',
#  'fed',
#  'spokesman',
#  'said',
#  'banking',
#  'system',
#  'excess',
#  'reserve',
#  'thursday,',
#  'monday',
#  'tuesday',
#  'deficit',
#  'friday',
#  'wedndsday.',
#  'produced',
#  'small',
#  'daily',
#  'average',
#  'deficit',
#  'week',
#  'whole.',
#  'two-week',
#  'period,',
#  'said',
#  'relatively',
#  'high',
#  'excess',
#  'reserve',
#  'daily',
#  'avearge,',
#  'almost',
#  'smallest',
#  'banks.',
#  'reuter',
#  '\x03']

# %%
filt_df['Lem_title'][96]  #notice that the word fund was not in the title, yet it correctly grabbed it
# Out:
# ['u.s.', 'bank', 'discount', 'borrowing', '310', 'mln', 'dlrs']

# %%
filt_df2 = data[data['Lem_title'].str.contains('finance', regex=False)]

# %%
filt_df2 = data[data['Lem_text'].str.contains('finance', regex=False)]

# %%
filt_df2.head()
# Out:
#                                              Lem_title  \
# 6               [red, lion, inn, file, plan, offering]
# 25    [banker, report, breakthrough, venezuelan, debt]
# 58   [key, u.s., tax, writer, seek, estate, tax, curb]
# 60      [canada's, wilson, seek, temporary, borrowing]
# 121    [venezuela, seek, 'flexibility', banks-azpurua]
#
#                         Date  \
# 6    26-FEB-1987 15:14:42.83
# 25   26-FEB-1987 15:36:44.78
# 58   26-FEB-1987 16:04:05.90
# 60   26-FEB-1987 16:05:36.23
# 121  26-FEB-1987 17:11:26.97
#
#                                               Lem_text
# 6    [red, lion, inn, limited, partnership, said, f...
# 25   [venezuela, bank, advisory, committee, agreed,...
# 58   [chairman, senior, republican, member, house, ...
# 60   [canadian, finance, minister, michael, wilson,...
# 121  [venezuela, seeking, 'constructive, flexible',...

# %%
filt_df2.shape  #quite a lot with finance, but when using the word money was not a lot of crossover bizarrely
# Out:
# (1239, 3)

# %%
#filt_finance =(filt_df[filt_df['Lem_text'].str.contains('finance', regex=False)])

# %%
#Filt_finance =(filt_df[filt_df['Lem_title'].str.contains('finance', regex=False)])

# %%
#filt_finance.head()
# Out:
#                                                Lem_title  \
# 337    [funaro, say, brazil, need, more,, faster, fin...
# 4879   [u.s., corporate, finance, -, bank, paper, pre...
# 5917   [french, finance, group, sdr, issue, domestic,...
# 15258   [ec, minister, likely, criticise, finance, idea]
#
#                           Date  \
# 337     2-MAR-1987 08:15:10.94
# 4879   16-MAR-1987 09:02:32.84
# 5917   18-MAR-1987 09:17:31.23
# 15258  26-APR-1987 06:44:58.79
#
#                                                 Lem_text
# 337    [brazil, would, suspended, payment, debt, owed...
# 4879   [debt, security, issued, major, u.s., bank, pr...
# 5917   [french, regional, financing, group, <societes...
# 15258  [plan, new-style, european, community, (ec), f...

# %%
#filt_finance.shape  #this tell me that very few articles regarding money have to do with the subject of finance, which seems strange
# Out:
# (4, 3)

# %%
filt_finance =(filt_df[filt_df['Lem_text'].str.contains('finance', regex=False)])

# %%
filt_finance =(filt_df[filt_df['Lem_title'].str.contains('finance', regex=False)])

# %%
filt_finance.shape  #more than twice more
# Out:
# (9, 3)

# %%
filt_fund =(filt_df2[filt_df2['Lem_text'].str.contains('fund', regex=False)])

# %%
filt_fund =(filt_df2[filt_df2['Lem_text'].str.contains('fund', regex=False)])

# %%
filt_money.head()
# Out:
#                                              Lem_title  \
# 164    [u.s., treasury, part, argentine, bridge, loan]
# 328          [manila, official, split, debt, strategy]
# 337  [funaro, say, brazil, need, more,, faster, fin...
# 824  [japan's, unemployment, rate, seen, rising, 3....
# 847   [japan, likely, let, u.s., bank, deal, security]
#
#                         Date  \
# 164  26-FEB-1987 18:07:18.31
# 328   2-MAR-1987 07:39:34.16
# 337   2-MAR-1987 08:15:10.94
# 824   3-MAR-1987 01:39:16.42
# 847   3-MAR-1987 05:05:45.88
#
#                                               Lem_text
# 164  [u.s., treasury, said, willing, participate, s...
# 328  [rift, occured, among, philippine, official, d...
# 337  [brazil, would, suspended, payment, debt, owed...
# 824  [japan's, unemployment, rate, expected, contin...
# 847  [japan, look, likely, allow, u.s., bank, condu...

# %%
#filt_money.shape  # this tells me that there exists articles that are about finance and contain the lem words of money
# Out:
# (130, 3)

# %%
filt_fund.shape  #more than double also and therefore fund is the better word to filter articles about money
# Out:
# (244, 3)

# %% [markdown]
# ### SYNSET

# %%
from nltk.corpus import wordnet as wn
for ss in wn.synsets('money'):
    print(ss, ss.hypernyms())
# Out:
# Synset('money.n.01') [Synset('medium_of_exchange.n.01')]
# Synset('money.n.02') [Synset('wealth.n.04')]
# Synset('money.n.03') [Synset('currency.n.01')]

# %%
from nltk.corpus import wordnet as wn
for ss in wn.synsets('fund'):
    print(ss, ss.hypernyms())
# Out:
# Synset('fund.n.01') [Synset('money.n.01')]
# Synset('store.n.02') [Synset('accumulation.n.04')]
# Synset('investment_company.n.01') [Synset('nondepository_financial_institution.n.01')]
# Synset('fund.v.01') [Synset('finance.v.01')]
# Synset('fund.v.02') [Synset('roll_up.v.02')]
# Synset('fund.v.03') [Synset('supply.v.01')]
# Synset('fund.v.04') [Synset('invest.v.01')]
# Synset('fund.v.05') [Synset('roll_up.v.02')]
# Synset('fund.v.06') [Synset('support.v.02')]

# %%
 print(wn.synset('money.n.01').definition())
# Out:
# the most common medium of exchange; functions as legal tender

# %%
 print(wn.synset('fund.n.01').definition())
# Out:
# a reserve of money set aside for some purpose

# %%
 print(wn.synset('finance.n.01').definition())
# Out:
# the commercial activity of providing funds and capital

# %%
wn.synset('money.n.01').lemmas()
# Out:
# [Lemma('money.n.01.money')]

# %%
wn.synset('fund.n.01').lemmas()
# Out:
# [Lemma('fund.n.01.fund'), Lemma('fund.n.01.monetary_fund')]

# %%
 [str(lemma.name()) for lemma in wn.synset('funds.n.01').lemmas()]
# Out:
# ['funds',
#  'finances',
#  'monetary_resource',
#  'cash_in_hand',
#  'pecuniary_resource']

# %%
# funds is more valuable so therefore I will change money to fund  
[str(lemma.name()) for lemma in wn.synset('money.n.01').lemmas()]  #I can see that that funds is much more inclusive
# Out:
# ['money']

# %%
wn.synset('finance.n.01').lemmas()
# Out:
# [Lemma('finance.n.01.finance')]

# %%
import nltk
from nltk.corpus import wordnet     #Import wordnet from the NLTK
first_word = wordnet.synset("money.n.01")
second_word = wordnet.synset("finance.v.01")
print('Similarity to finance as a verb: ' + str(first_word.wup_similarity(second_word)))
first_word = wordnet.synset("money.n.02")
second_word = wordnet.synset("finance.n.01")
print('Similarity to finance as a noun an: ' + str(first_word.wup_similarity(second_word)))
# Out:
# Similarity to finance as a verb: 0.15384615384615385
# Similarity to finance as a noun an: 0.25

# %%
first_word = wordnet.synset("fund.n.01")
second_word = wordnet.synset("finance.v.01")
print('Similarity to finance as a verb: ' + str(first_word.wup_similarity(second_word)))
first_word = wordnet.synset("fund.n.02")
second_word = wordnet.synset("finance.n.01")
print('Similarity to finance as a noun an: ' + str(first_word.wup_similarity(second_word)))
# Out:
# Similarity to finance as a verb: 0.14285714285714285
# Similarity to finance as a noun an: 0.19047619047619047

# %%
import nltk
from nltk.corpus import wordnet     #Import wordnet from the NLTK
first_word = wordnet.synset("fund.n.01")
second_word = wordnet.synset("money.n.01")
print('Similarity to between fund and money: ' + str(first_word.wup_similarity(second_word)))
# Out:
# Similarity to between fund and money: 0.9333333333333333

# %% [markdown]
# ## Hypernyms and Hyponyms –
#
# Hypernyms: More abstract terms
# Hyponyms: More specific terms.
#
# Both come to picture as Synsets are organized in a structure similar to that of an inheritance tree. This tree can be traced all the way up to a root hypernym. Hypernyms provide a way to categorize and group words based on their similarity to each other.

# %%
from nltk.corpus import wordnet
syn = wordnet.synsets('money')[0]
  
print ("Synset name :  ", syn.name())
  
print ("\nSynset abstract term :  ", syn.hypernyms())
  
print ("\nSynset specific term :  ", 
       syn.hypernyms()[0].hyponyms())
  
syn.root_hypernyms()
  
print ("\nSynset root hypernerm :  ", syn.root_hypernyms())
# Out:
# Synset name :   money.n.01
#
# Synset abstract term :   [Synset('medium_of_exchange.n.01')]
#
# Synset specific term :   [Synset('currency.n.01'), Synset('money.n.01'), Synset('tender.n.01')]
#
# Synset root hypernerm :   [Synset('entity.n.01')]

# %%
#corfirm using wup

first_word.wup_similarity(second_word)
# Out:
# 0.9333333333333333

# %%
sorted(first_word.common_hypernyms(second_word))
# Out:
# [Synset('abstraction.n.06'),
#  Synset('entity.n.01'),
#  Synset('measure.n.02'),
#  Synset('medium_of_exchange.n.01'),
#  Synset('money.n.01'),
#  Synset('standard.n.01'),
#  Synset('system_of_measurement.n.01')]

# %%
from nltk.corpus import wordnet as wn

relative = wn.synsets('fund', 'n')[0]
hypos = lambda s:s.hyponyms()

print(list(relative.closure(hypos)))
# Out:
# [Synset('budget.n.01'), Synset('deposit.n.04'), Synset('mutual_fund.n.01'), Synset('pension_fund.n.01'), Synset('petty_cash.n.01'), Synset('revolving_fund.n.01'), Synset('savings.n.01'), Synset('sinking_fund.n.01'), Synset('slush_fund.n.01'), Synset('trust_fund.n.01'), Synset('war_chest.n.01'), Synset('civil_list.n.01'), Synset('operating_budget.n.01'), Synset('demand_deposit.n.01'), Synset('exchange_traded_fund.n.01'), Synset('index_fund.n.01')]

# %%
from nltk.corpus import wordnet as wn

relative = wn.synsets('fund', 'n')[0]
hypers = lambda s:s.hypernyms()

print(list(relative.closure(hypers)))
# Out:
# [Synset('money.n.01'), Synset('medium_of_exchange.n.01'), Synset('standard.n.01'), Synset('system_of_measurement.n.01'), Synset('measure.n.02'), Synset('abstraction.n.06'), Synset('entity.n.01')]

# %%
money = wn.synset('fund.n.01')  #first look up the first entry for money
print(money)
# Out:
# Synset('fund.n.01')

# %% [markdown]
# ### from nltk.corpus import wordnet as wn
# import networkx as nx
#
# def closure_graph(synset, fn):
#     seen = set()
#     graph = nx.DiGraph()
#
#     def recurse(s):
#         if not s in seen:
#             seen.add(s)
#             graph.add_node(s.name)
#             for s1 in fn(s):
#                 graph.add_node(s1.name)
#                 graph.add_edge(s.name, s1.name)
#                 recurse(s1)
#
#     recurse(synset)
#     return graph

# %%
graph = closure_graph(money,
                      lambda s: s.hypernyms())

# %%
print(graph)
# Out:
# DiGraph with 7 nodes and 6 edges

# %%
sorted(wn.synset('money.n.01').lemmas('spa'))
# Out:
# [Lemma('money.n.01.dinero')]

# %%
filt_df3 = data[data['Lem_text'].str.contains('dinero', regex=False)]

# %%
filt_df3.head(0)
# Out:
# Empty DataFrame
# Columns: [Lem_title, Date, Lem_text]
# Index: []
